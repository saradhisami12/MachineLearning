# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\sarad\Downloads\Train_Data.csv")
print(df.shape)
df.head()
# Out:
# (4999, 9)
#                                                 text           author  \
# 0  i must be retarded i thought it meant con lawl...     ['calantus']
# 1  DOWNMODDED FOR IRRELEVANCE? ISN'T THAT HOW THI...   ['Shadowrose']
# 2  THAT WAS SUPPOSED TO MEAN " BY A PLACE WHERE P...    ['NExusRush']
# 3   I THOUGHT EVERYONE DID; ITS FUCKING DELICIOUS :\  ['R0N_SWANS0N']
# 4  Great work, Zhesbe! I'd give you a raise but y...      ['reddums']
#
#    controversiality                                        parent_text  \
# 0                 0  It's quite unfair to call Hillary Clinton a "c...
# 1                 0                      upmodded for awesome kindness
# 2                 0  What the hell does "because its by a golf cour...
# 3                 0  NICE TRY JENNIFER!  I KNOW IT'S YOU AND I KNOW...
# 4                 0               "HEY BOSS COME LOOK AT WHAT I DID!"
#
#    parent_score  parent_votes parent_author  parent_controversiality  Score
# 0           245           245       Whisper                        0     -8
# 1            32            32       b3mus3d                        0    -16
# 2            12            12  mr_jellyneck                        0     -7
# 3           117           117        ometzo                        0     67
# 4          1933          1933        Zhesbe                        0   1348

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   text                     4999 non-null   object
#  1   author                   4999 non-null   object
#  2   controversiality         4999 non-null   int64
#  3   parent_text              4999 non-null   object
#  4   parent_score             4999 non-null   int64
#  5   parent_votes             4999 non-null   int64
#  6   parent_author            4999 non-null   object
#  7   parent_controversiality  4999 non-null   int64
#  8   Score                    4999 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 351.6+ KB

# %%
cols = ['text', 'author', 'controversiality', 'parent_text', 'parent_score', 'parent_votes',
'parent_author', 'parent_controversiality', 'Score']
for col in cols:
    print(col,':',df[col].nunique())
# Out:
# text : 4992
# author : 4317
# controversiality : 2
# parent_text : 4992
# parent_score : 1001
# parent_votes : 1001
# parent_author : 4448
# parent_controversiality : 2
# Score : 572

# %%
df['score vs. votes'] = df['parent_score']==df['parent_votes']
df['score vs. votes'].nunique()
# Out:
# 1

# %%
df.drop(['parent_votes', 'score vs. votes'], axis= 1, inplace=True)
df.head()
# Out:
#                                                 text           author  \
# 0  i must be retarded i thought it meant con lawl...     ['calantus']
# 1  DOWNMODDED FOR IRRELEVANCE? ISN'T THAT HOW THI...   ['Shadowrose']
# 2  THAT WAS SUPPOSED TO MEAN " BY A PLACE WHERE P...    ['NExusRush']
# 3   I THOUGHT EVERYONE DID; ITS FUCKING DELICIOUS :\  ['R0N_SWANS0N']
# 4  Great work, Zhesbe! I'd give you a raise but y...      ['reddums']
#
#    controversiality                                        parent_text  \
# 0                 0  It's quite unfair to call Hillary Clinton a "c...
# 1                 0                      upmodded for awesome kindness
# 2                 0  What the hell does "because its by a golf cour...
# 3                 0  NICE TRY JENNIFER!  I KNOW IT'S YOU AND I KNOW...
# 4                 0               "HEY BOSS COME LOOK AT WHAT I DID!"
#
#    parent_score parent_author  parent_controversiality  Score
# 0           245       Whisper                        0     -8
# 1            32       b3mus3d                        0    -16
# 2            12  mr_jellyneck                        0     -7
# 3           117        ometzo                        0     67
# 4          1933        Zhesbe                        0   1348

# %%
cor = df.corr()
sns.heatmap(cor)
# Out:
# C:\Users\sarad\AppData\Local\Temp\ipykernel_3872\2380579405.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = df.corr()
# <Axes: >

# %%
categorical_cols = ['text','author','parent_text','parent_author']
for col in df[categorical_cols]:
    df[col] = df[col].str.lower()
    df[col] = df[col].str.strip()
df.head()
# Out:
#                                                 text           author  \
# 0  i must be retarded i thought it meant con lawl...     ['calantus']
# 1  downmodded for irrelevance? isn't that how thi...   ['shadowrose']
# 2  that was supposed to mean " by a place where p...    ['nexusrush']
# 3   i thought everyone did; its fucking delicious :\  ['r0n_swans0n']
# 4  great work, zhesbe! i'd give you a raise but y...      ['reddums']
#
#    controversiality                                        parent_text  \
# 0                 0  it's quite unfair to call hillary clinton a "c...
# 1                 0                      upmodded for awesome kindness
# 2                 0  what the hell does "because its by a golf cour...
# 3                 0  nice try jennifer!  i know it's you and i know...
# 4                 0                "hey boss come look at what i did!"
#
#    parent_score parent_author  parent_controversiality  Score
# 0           245       whisper                        0     -8
# 1            32       b3mus3d                        0    -16
# 2            12  mr_jellyneck                        0     -7
# 3           117        ometzo                        0     67
# 4          1933        zhesbe                        0   1348

# %%
import string

for col in df[categorical_cols]:
    df[col] = df[col].apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
df.head()
# Out:
#                                                 text      author  \
# 0  i must be retarded i thought it meant con lawl...    calantus
# 1  downmodded for irrelevance isnt that how this ...  shadowrose
# 2  that was supposed to mean  by a place where pe...   nexusrush
# 3      i thought everyone did its fucking delicious   r0nswans0n
# 4  great work zhesbe id give you a raise but you ...     reddums
#
#    controversiality                                        parent_text  \
# 0                 0  its quite unfair to call hillary clinton a cun...
# 1                 0                      upmodded for awesome kindness
# 2                 0  what the hell does because its by a golf cours...
# 3                 0  nice try jennifer  i know its you and i know y...
# 4                 0                   hey boss come look at what i did
#
#    parent_score parent_author  parent_controversiality  Score
# 0           245       whisper                        0     -8
# 1            32       b3mus3d                        0    -16
# 2            12   mrjellyneck                        0     -7
# 3           117        ometzo                        0     67
# 4          1933        zhesbe                        0   1348

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize 

def text_tokens(row):
    text = row['text']
    tokens = word_tokenize(text)
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words
df['text_tokens'] = df.apply(text_tokens, axis=1)

def parent_text_tokens(row):
    parent_text = row['parent_text']
    tokens = word_tokenize(parent_text)
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words
df['parent_text_tokens'] = df.apply(parent_text_tokens, axis=1)

df.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sarad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sarad\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                 text      author  \
# 0  i must be retarded i thought it meant con lawl...    calantus
# 1  downmodded for irrelevance isnt that how this ...  shadowrose
# 2  that was supposed to mean  by a place where pe...   nexusrush
# 3      i thought everyone did its fucking delicious   r0nswans0n
# 4  great work zhesbe id give you a raise but you ...     reddums
#
#    controversiality                                        parent_text  \
# 0                 0  its quite unfair to call hillary clinton a cun...
# 1                 0                      upmodded for awesome kindness
# 2                 0  what the hell does because its by a golf cours...
# 3                 0  nice try jennifer  i know its you and i know y...
# 4                 0                   hey boss come look at what i did
#
#    parent_score parent_author  parent_controversiality  Score  \
# 0           245       whisper                        0     -8
# 1            32       b3mus3d                        0    -16
# 2            12   mrjellyneck                        0     -7
# 3           117        ometzo                        0     67
# 4          1933        zhesbe                        0   1348
#
#                                          text_tokens  \
# 0  [i, must, be, retarded, i, thought, it, meant,...
# 1  [downmodded, for, irrelevance, isnt, that, how...
# 2  [that, was, supposed, to, mean, by, a, place, ...
# 3  [i, thought, everyone, did, its, fucking, deli...
# 4  [great, work, zhesbe, id, give, you, a, raise,...
#
#                                   parent_text_tokens
# 0  [its, quite, unfair, to, call, hillary, clinto...
# 1                 [upmodded, for, awesome, kindness]
# 2  [what, the, hell, does, because, its, by, a, g...
# 3  [nice, try, jennifer, i, know, its, you, and, ...
# 4          [hey, boss, come, look, at, what, i, did]

# %%
stop_words = stopwords.words('english')

tokens_cols = ['text_tokens','parent_text_tokens']

for col in tokens_cols:
    df[col] = df[col].apply(lambda x: ' '.join([w for w in x if w not in (stop_words)]))
df.head()
# Out:
#                                                 text      author  \
# 0  i must be retarded i thought it meant con lawl...    calantus
# 1  downmodded for irrelevance isnt that how this ...  shadowrose
# 2  that was supposed to mean  by a place where pe...   nexusrush
# 3      i thought everyone did its fucking delicious   r0nswans0n
# 4  great work zhesbe id give you a raise but you ...     reddums
#
#    controversiality                                        parent_text  \
# 0                 0  its quite unfair to call hillary clinton a cun...
# 1                 0                      upmodded for awesome kindness
# 2                 0  what the hell does because its by a golf cours...
# 3                 0  nice try jennifer  i know its you and i know y...
# 4                 0                   hey boss come look at what i did
#
#    parent_score parent_author  parent_controversiality  Score  \
# 0           245       whisper                        0     -8
# 1            32       b3mus3d                        0    -16
# 2            12   mrjellyneck                        0     -7
# 3           117        ometzo                        0     67
# 4          1933        zhesbe                        0   1348
#
#                                          text_tokens  \
# 0  must retarded thought meant con lawl oh well work
# 1                  downmodded irrelevance isnt works
# 2  supposed mean place people undoubtedly snake b...
# 3                 thought everyone fucking delicious
# 4       great work zhesbe id give raise seem handled
#
#                                   parent_text_tokens
# 0  quite unfair call hillary clinton cunt lacks d...
# 1                          upmodded awesome kindness
# 2  hell golf course anything think bunch rich whi...
# 3      nice try jennifer know know like baba ganoush
# 4                                 hey boss come look

# %%
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatize_function = lambda x: [lemmatizer.lemmatize(str(word)) for word in x.split()]

for col in tokens_cols:
    df[col] = df[col].apply(lemmatize_function)
df.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sarad\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                 text      author  \
# 0  i must be retarded i thought it meant con lawl...    calantus
# 1  downmodded for irrelevance isnt that how this ...  shadowrose
# 2  that was supposed to mean  by a place where pe...   nexusrush
# 3      i thought everyone did its fucking delicious   r0nswans0n
# 4  great work zhesbe id give you a raise but you ...     reddums
#
#    controversiality                                        parent_text  \
# 0                 0  its quite unfair to call hillary clinton a cun...
# 1                 0                      upmodded for awesome kindness
# 2                 0  what the hell does because its by a golf cours...
# 3                 0  nice try jennifer  i know its you and i know y...
# 4                 0                   hey boss come look at what i did
#
#    parent_score parent_author  parent_controversiality  Score  \
# 0           245       whisper                        0     -8
# 1            32       b3mus3d                        0    -16
# 2            12   mrjellyneck                        0     -7
# 3           117        ometzo                        0     67
# 4          1933        zhesbe                        0   1348
#
#                                          text_tokens  \
# 0  [must, retarded, thought, meant, con, lawl, oh...
# 1              [downmodded, irrelevance, isnt, work]
# 2  [supposed, mean, place, people, undoubtedly, s...
# 3            [thought, everyone, fucking, delicious]
# 4  [great, work, zhesbe, id, give, raise, seem, h...
#
#                                   parent_text_tokens
# 0  [quite, unfair, call, hillary, clinton, cunt, ...
# 1                      [upmodded, awesome, kindness]
# 2  [hell, golf, course, anything, think, bunch, r...
# 3  [nice, try, jennifer, know, know, like, baba, ...
# 4                             [hey, bos, come, look]

# %%
df['text']= df['text_tokens'].apply(lambda x: ' '.join(x))
df['parent_text']= df['parent_text_tokens'].apply(lambda x: ' '.join(x))
df.drop(['text_tokens', 'parent_text_tokens'], axis=1, inplace= True)

df.head()
# Out:
#                                                 text      author  \
# 0  must retarded thought meant con lawl oh well work    calantus
# 1                   downmodded irrelevance isnt work  shadowrose
# 2  supposed mean place people undoubtedly snake b...   nexusrush
# 3                 thought everyone fucking delicious  r0nswans0n
# 4       great work zhesbe id give raise seem handled     reddums
#
#    controversiality                                        parent_text  \
# 0                 0  quite unfair call hillary clinton cunt lack de...
# 1                 0                          upmodded awesome kindness
# 2                 0  hell golf course anything think bunch rich whi...
# 3                 0      nice try jennifer know know like baba ganoush
# 4                 0                                  hey bos come look
#
#    parent_score parent_author  parent_controversiality  Score
# 0           245       whisper                        0     -8
# 1            32       b3mus3d                        0    -16
# 2            12   mrjellyneck                        0     -7
# 3           117        ometzo                        0     67
# 4          1933        zhesbe                        0   1348

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import plotly.express as px
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
from wordcloud import WordCloud

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\sarad\anac py\lib\site-packages (1.3.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\sarad\anac py\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sarad\anac py\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sarad\anac py\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sarad\anac py\lib\site-packages (from scikit-learn) (2.2.0)

# %%
vectorizer = CountVectorizer()
text = vectorizer.fit_transform(df['text']).toarray()
text = pd.DataFrame(text, columns= vectorizer.get_feature_names_out())

text.shape
# Out:
# (4999, 13109)

# %%
vectorizer1 = TfidfVectorizer(max_features=50,min_df=1,max_df=0.7)
text_tf_idf = vectorizer1.fit_transform(df['text']).toarray()
text_tf_idf = pd.DataFrame(text_tf_idf, columns=vectorizer1.get_feature_names_out())

text_tf_idf.shape
# Out:
# (4999, 50)

# %%
num_cols = df[['controversiality', 'parent_score', 'parent_controversiality']]
x = pd.concat([text_tf_idf, num_cols], axis=1)
y = df['Score']

# %%
from sklearn.model_selection import train_test_split

# split the data
x_train, x_val, y_train, y_val = train_test_split(x,y,test_size=0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)

pred_y = lr.predict(x_val)

# %%
from sklearn.metrics import mean_squared_error
print('Root Mean Squared Error is: ', np.sqrt(mean_squared_error(y_val, pred_y)))
# Out:
# Root Mean Squared Error is:  147.63289313356805

# %%
from xgboost import XGBRegressor

xgbReg = XGBRegressor(verbosity=0)
xgbReg.fit(x_train, y_train)

pred_y1 = xgbReg.predict(x_val)

# Root mean squared error 
print('Root Mean Squared Error is: ', np.sqrt(mean_squared_error(y_val, pred_y1)))
# Out:
# Root Mean Squared Error is:  162.88786930668726

# %%
param_grid = {'n_neighbors': np.arange(1, 100)}
knn = KNeighborsRegressor()
knn_cv = GridSearchCV(knn, param_grid, cv=5)
knn_cv.fit(x_train, y_train)
knn_cv.best_params_
# Out:
# {'n_neighbors': 50}

# %%
knn = KNeighborsRegressor(n_neighbors = 50)
knn.fit(x_train, y_train)

pred_y2 = knn.predict(x_val)

# Root mean squared error 
print('Root Mean Squared Error is: ', np.sqrt(mean_squared_error(y_val, pred_y2)))
# Out:
# Root Mean Squared Error is:  141.3331602009946

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
param_grid = {'n_estimators': np.arange(1, 50), 'max_depth': np.arange(1, 50)}

RFRegressor = RandomForestRegressor()
RFRegressor_cv = GridSearchCV(RFRegressor, param_grid, cv=5)
RFRegressor_cv.fit(x_train, y_train)
RFRegressor_cv.best_params_

# %%
randForest = RandomForestRegressor(n_estimators=9, max_depth=3, max_features='auto')
randForest.fit(x_train, y_train)

pred_y3 = randForest.predict(x_val)

print('Root Mean Squared Error is: ', np.sqrt(mean_squared_error(y_val, pred_y3)))

# %%
test_data = pd.read_csv(r"C:\Users\sarad\Downloads\Test_Data.csv")
test_data.head()
# Out:
#                                                 text            author  \
# 0  Big deal. He once fought in the Napoleonic war...      ['RecQuery']
# 1  I don't think the animal cares, either way, it...        ['N4N4KI']
# 2  &GT; IT'S FAIRLY OBVIOUS YOU HAVE AN AGENDA HE...    ['cometparty']
# 3  It's probably due to their skin looking supple...     ['[deleted]']
# 4  kendrick lamar. he's like a poverty lupe fiasc...  ['purrppassion']
#
#    controversiality                                        parent_text  \
# 0                 0  Big deal. He was once shot with three arrows a...
# 1                 0  Animal cruelty is not a joke.  It is not the s...
# 2                 0  &gt;**You people** have time and time again sh...
# 3                 0  I like women who are either naturally tan or a...
# 4                 0  who has the most overrated discography in hip ...
#
#    parent_score  parent_votes       parent_author  parent_controversiality
# 0           438           438  illchopyourfaceoff                        0
# 1            38            38                 0_o                        0
# 2            16            16           [deleted]                        0
# 3           902           902           [deleted]                        0
# 4            33            33         mr2good4you                        0

# %% [raw]
# test_data['text'] = test_data['text'].str.lower()
# test_data['text'] = test_data['text'].str.strip()
#
# test_data['text'] = test_data['text'].apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
#
# test_data['text_tokens'] = df.apply(text_tokens, axis=1)
#
# test_data['text_tokens'] = test_data['text_tokens'].apply(lambda x: ' '.join([w for w in x if w not in (stop_words)]))
#
# test_data['text_tokens'] = test_data['text_tokens'].apply(lemmatize_function)
#
# test_data['text']= test_data['text_tokens'].apply(lambda x: ' '.join(x))
# test_data.drop(['text_tokens'], axis=1, inplace= True)
#
# text_data_tf_idf = vectorizer1.fit_transform(test_data['text']).toarray()
# test_num = test_data[['controversiality','parent_score', 'parent_controversiality']]
#
# test = pd.concat([text_data_tf_idf, test_num], axis=1)
# predict_test_y = lr.predict(test)
# predict_test_y1 = xgbReg.predict(test)
# predict_test_y2 = knn.predict(test)
# predict_test_y3 = randForest.predict(test)
# res = pd.DataFrame(predict_test_y2)
# res.index = test_data.index
# res.columns = ["prediction"]
# res.to_csv("submission6.csv")
